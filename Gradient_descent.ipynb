# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("0000000000002417_training_boston_x_y_train.csv")
data.head()
# Out:
#      # CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0 -0.407850 -0.487722 -1.266023 -0.272599 -0.576134  1.239974  0.840122
# 1 -0.407374 -0.487722  0.247057 -0.272599 -1.016689  0.001946 -0.838337
# 2  0.125179 -0.487722  1.015999 -0.272599  1.367490 -0.439699  0.687212
# 3  0.028304 -0.487722  1.015999 -0.272599  1.859875 -0.047918  0.801005
# 4 -0.412408 -0.487722 -0.969827 -0.272599 -0.913029 -0.384137 -0.834781
#
#         DIS       RAD       TAX   PTRATIO         B     LSTAT     Y
# 0 -0.520264 -0.752922 -1.278354 -0.303094  0.410571 -1.097990  37.9
# 1  0.336351 -0.523001 -0.060801  0.113032  0.291169 -0.520474  21.4
# 2 -0.577309  1.661245  1.530926  0.806576 -3.795795  0.891076  12.7
# 3 -0.712836  1.661245  1.530926  0.806576 -0.066050  0.215438  19.9
# 4  0.300508 -0.752922 -0.957633  0.020560  0.431074  0.029007  22.5

# %%
X = data.drop(columns = ' Y')
Y = data[' Y']

# %%
from sklearn.linear_model import LinearRegression
alg1 = LinearRegression()

# %%
alg1.fit(X,Y)
# Out:
# LinearRegression()

# %%
m = alg1.coef_[0]
a = alg1.coef_[1]
b = alg1.coef_[2]
c = alg1.coef_[3]
d = alg1.coef_[4]
e = alg1.coef_[5]
f = alg1.coef_[6]
g = alg1.coef_[7]
h = alg1.coef_[8]
i = alg1.coef_[9]
j = alg1.coef_[10]
k = alg1.coef_[11]
l = alg1.coef_[12]
m
# Out:
# -0.9380807657383498

# %%
c = alg1.intercept_
c
# Out:
# 22.677233263858266

# %%
test_data = pd.read_csv("0000000000002417_test_boston_x_test.csv")

test_data.head()
# Out:
#    2.91816626  -0.48772236  1.01599907  -0.27259857  0.36544404  -1.60934343  \
# 0   -0.403392    -0.487722    0.406098    -0.272599   -1.016689     0.560412
# 1   -0.413178    -0.487722    0.115738    -0.272599    0.158124    -0.234548
# 2   -0.412649     0.413589   -0.802031    -0.272599   -0.999412    -0.408356
# 3   -0.405882    -0.487722   -0.375976    -0.272599   -0.299707    -0.127698
# 4   -0.228814    -0.487722    1.568995    -0.272599    0.598679    -1.803097
#
#    1.11749449  -1.04849446  1.66124525  1.53092646  0.80657583  -1.59755122  \
# 0   -1.332629     1.029344   -0.637962   -0.708183   -1.135347     0.441052
# 1    0.288933    -0.716639   -0.982843   -0.803212    1.176466     0.441052
# 2   -1.677566     1.435452   -0.637962   -0.981390   -0.765457     0.441052
# 3   -0.504068    -0.483566   -0.523001   -0.143951    1.130230     0.403663
# 4    1.117494    -1.119800   -0.637962    0.170831    1.268938     0.441052
#
#    1.04106182
# 0   -0.894738
# 1   -0.500850
# ...

# %%
X_1 = test_data['2.91816626']
Y_1 = test_data['1.04106182']
curr_pos = (0,0)
plt.scatter(X_1,Y_1)
plt.show()

# %%
lr = 0.001
epochs =1000
n = float(len(X))
for i in range(len(X)):
    Y_pred = m*X_1+c
    D_m = (-2/n)*sum(X_1*(Y_pred - Y_1))
    D_c = (-2/n)*sum(Y_pred - Y_1)
    m = m - lr * D_m
    c = c - lr * D_c
    print(m,c)
# Out:
# 9.670180153524734 23.052595640719268
# 9.672042583542902 23.067437290780788
# 9.673904856876927 23.082288707377167
# 9.675766972937954 23.097149897010816
# 9.677628931136562 23.112020866188498
# 9.679490730882774 23.126901621421332
# 9.681352371586046 23.141792169224804
# 9.68321385265527 23.15669251611876
# 9.685075173498774 23.17160266862742
# 9.686936333524322 23.18652263327936
# 9.688797332139115 23.201452416607545
# 9.690658168749785 23.21639202514931
# 9.6925188427624 23.23134146544637
# 9.694379353582462 23.246300744044817
# 9.696239700614909 23.261269867495134
# 9.698099883264105 23.276248842352192
# 9.69995990093385 23.29123767517525
# 9.70181975302738 23.306236372527962
# 9.703679438947354 23.321244940978378
# 9.705538958095872 23.33626338709895
# 9.707398309874456 23.35129171746653
# 9.709257493684063 23.36632993866238
# 9.711116508925079 23.381378057272162
# 9.712975354997319 23.396436079885962
# 9.714834031300025 23.411504013098273
# 9.716692537231872 23.426581863508005
# ...

# %%
# making predictions
Y_pred = m*X_1+c
plt.scatter(X_1,Y_1)
plt.scatter(X_1,Y_pred)
plt.show()
